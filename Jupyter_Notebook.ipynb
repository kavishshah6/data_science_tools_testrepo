# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Kavish Shah**
# 2nd Year Student at Nirma University, Ahmedabad

# %% [markdown]
# *I am interested in data science because I am curious to see how the raw data is used systematically to get predictions about the future trends. We live in a world full of data where every small sensor produces gigabytes of data.*

# %% [markdown]
# ### Square and cube of number 6

# %%
print('Square of 6 is = '+str(6*6))
print('Cube of 6 is = '+str(6*6*6))
# Out:
# Square of 6 is = 36
# Cube of 6 is = 216

# %% [markdown]
# ~~Strike through~~
# 1. Cheese
# 2. Carrot
# 3. Coconut
# - Cheese
# - Carrot
# - Coconut
# > This is a blocked quote
